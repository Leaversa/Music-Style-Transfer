# %% [markdown]
# # Imports

# %%
import pretty_midi
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from collections import Counter
import pickle
from pretty_midi import PrettyMIDI
from IPython.display import Audio

# %% [markdown]
# # Dataset Download

# %% [markdown]
# # Data Pre-Processing

# %%
##########################################
# Step 0: Data Pre-Processing
##########################################
def load_midi_files(midi_dir, style_label):
    midi_data_list = []
    for filename in os.listdir(midi_dir):
        if filename.lower().endswith(('.mid', '.midi')):
            try:
                midi_path = os.path.join(midi_dir, filename)
                midi_data = pretty_midi.PrettyMIDI(midi_path)
                midi_data_list.append((midi_data, style_label))  # Add style label
            except Exception as e:
                print(f"Error loading {filename}: {e}")
    return midi_data_list

def tokenize_midi(midi_data, time_resolution=0.05):
    """
    Convert MIDI data to a sequence of tokens.

    Parameters:
    - midi_data: a PrettyMIDI object.
    - time_resolution: the smallest time unit (in seconds) for a time shift.

    Token types include:
      - TIME_SHIFT_n: advance time by n * time_resolution seconds.
      - NOTE_ON_pitch_velocity: a note-on event with the given pitch and velocity.
      - NOTE_OFF_pitch: a note-off event for the given pitch.
    """
    events = []

    # Iterate through all instruments in the MIDI file
    for instrument in midi_data.instruments:
        # Optionally, skip drum instruments if not needed
        if instrument.is_drum:
            continue
        # Add note on/off events for each note
        for note in instrument.notes:
            events.append((note.start, "note_on", note.pitch, note.velocity))
            events.append((note.end, "note_off", note.pitch))

    # Sort events by time
    events.sort(key=lambda x: x[0])

    tokens = []
    previous_time = 0.0

    # Create tokens, including time shift tokens if there is a gap between events
    for event in events:
        current_time = event[0]
        time_diff = current_time - previous_time

        # Quantize the time difference based on the resolution
        steps = int(round(time_diff / time_resolution))
        if steps > 0:
            tokens.append(f"TIME_SHIFT_{steps}")

        # Append the note event token
        if event[1] == "note_on":
            tokens.append(f"NOTE_ON_{event[2]}_{event[3]}")
        elif event[1] == "note_off":
            tokens.append(f"NOTE_OFF_{event[2]}")

        previous_time = current_time

    return tokens

# %%
##########################################
# Step 1: Build Vocabulary from Token Data
##########################################
def build_vocab(token_sequences, min_freq=1):
    """
    Build a vocabulary from tokenized sequences.
    Special tokens: <PAD>, <SOS>, <EOS>, <UNK>
    """
    counter = Counter()
    for seq in token_sequences:
        counter.update(seq)
    tokens = [token for token, count in counter.items() if count >= min_freq]
    special_tokens = ["<PAD>", "<SOS>", "<EOS>", "<UNK>"]
    vocab = special_tokens + tokens
    token_to_idx = {token: idx for idx, token in enumerate(vocab)}
    idx_to_token = {idx: token for token, idx in token_to_idx.items()}
    return token_to_idx, idx_to_token

# %%
##########################################
# Step 2: Create a Custom Dataset
##########################################
class TokenDataset(Dataset):
    def __init__(self, token_sequences, token_to_idx, max_length=100):
        """
        token_sequences: List of token lists.
        token_to_idx: Dictionary mapping tokens to indices.
        max_length: Maximum length of a sequence (will pad or truncate).
        """
        self.sequences = token_sequences
        self.token_to_idx = token_to_idx
        self.max_length = max_length

    def __len__(self):
        return len(self.sequences)

    """
    def __getitem__(self, idx):
        seq = self.sequences[idx]
        # Add Start Of Sequence and End Of Sequence tokens
        seq = ["<SOS>"] + seq + ["<EOS>"]
        # Convert tokens to indices, using <UNK> if token not found
        seq_idx = [self.token_to_idx.get(token, self.token_to_idx["<UNK>"]) for token in seq]
        # Pad sequence if necessary
        if len(seq_idx) < self.max_length:
            seq_idx += [self.token_to_idx["<PAD>"]] * (self.max_length - len(seq_idx))
        else:
            seq_idx = seq_idx[:self.max_length]
        # Prepare input (all tokens except last) and target (all tokens except first)
        input_seq = torch.tensor(seq_idx[:-1], dtype=torch.long)
        target_seq = torch.tensor(seq_idx[1:], dtype=torch.long)
        return input_seq, target_seq
    """


    def __getitem__(self, idx):
        seq = self.sequences[idx]
        # If seq is a string, convert it into a list of tokens (assuming tokens are space-separated)
        if isinstance(seq, str):
            seq = seq.split()

        # Add Start Of Sequence and End Of Sequence tokens
        seq = ["<SOS>"] + seq + ["<EOS>"]
        # Convert tokens to indices, using <UNK> if token not found
        seq_idx = [self.token_to_idx.get(token, self.token_to_idx["<UNK>"]) for token in seq]
        # Pad sequence if necessary
        if len(seq_idx) < self.max_length:
            seq_idx += [self.token_to_idx["<PAD>"]] * (self.max_length - len(seq_idx))
        else:
            seq_idx = seq_idx[:self.max_length]
        # Prepare input (all tokens except last) and target (all tokens except first)
        input_seq = torch.tensor(seq_idx[:-1], dtype=torch.long)
        target_seq = torch.tensor(seq_idx[1:], dtype=torch.long)
        return input_seq, target_seq

# %% [markdown]
# # Model

# %%
##########################################
# Step 3: Define the VAE Model
##########################################
class MusicVAE(nn.Module):
    def __init__(self, vocab_size, embed_size=128, hidden_size=256, latent_size=64, num_layers=1):
        super(MusicVAE, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.encoder_lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.fc_mu = nn.Linear(hidden_size, latent_size)
        self.fc_logvar = nn.Linear(hidden_size, latent_size)

        self.latent_to_hidden = nn.Linear(latent_size, hidden_size)
        self.decoder_lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.outputs_fc = nn.Linear(hidden_size, vocab_size)

    def encode(self, x):
        embedded = self.embedding(x)  # (batch, seq_len, embed_size)
        _, (h, _) = self.encoder_lstm(embedded)
        # Use the last hidden state from the final layer
        h_last = h[-1]  # (batch, hidden_size)
        mu = self.fc_mu(h_last)
        logvar = self.fc_logvar(h_last)
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z, input_seq):
        # Prepare initial hidden state for decoder from latent vector
        hidden = self.latent_to_hidden(z)
        hidden = hidden.unsqueeze(0)  # (1, batch, hidden_size)
        cell = torch.zeros_like(hidden)  # Initialize cell state to zeros
        embedded = self.embedding(input_seq)
        output, _ = self.decoder_lstm(embedded, (hidden, cell))
        logits = self.outputs_fc(output)  # (batch, seq_len, vocab_size)
        return logits

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        logits = self.decode(z, x)
        return logits, mu, logvar

# %%
##########################################
# Step 4: Define the Loss Function
##########################################
def loss_function(logits, targets, mu, logvar):
    # Reconstruction loss: Flatten predictions and targets
    reconstruction_loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=0)
    # KL divergence loss
    kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    kl_loss /= logits.size(0)  # normalize by batch size
    return reconstruction_loss + kl_loss

# %%
##########################################
# Step 5: Training Loop
##########################################
def train_vae(model, dataloader, optimizer, epochs=10, device='cpu'):
    model.train()
    model.to(device)
    for epoch in range(epochs):
        total_loss = 0.0
        for input_seq, target_seq in dataloader:
            input_seq = input_seq.to(device)
            target_seq = target_seq.to(device)
            optimizer.zero_grad()
            logits, mu, logvar = model(input_seq)
            loss = loss_function(logits, target_seq, mu, logvar)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch + 1}/{epochs}, Loss: {avg_loss:.4f}")

# %% [markdown]
# # Training

# %%
# Load MIDI files for Training.
midi_directory = './datasets/MIDI-VAE_PaperData/Classic and Bach/barock/Bach/Bwv001- 400 Chorales'
midi_files = load_midi_files(midi_directory)

output_dir = './models/music_vae/'

# Tokenize all MIDI files into a list of sequences
tokenized_data = []
for i, midi_data in enumerate(midi_files):
    tokens = tokenize_midi(midi_data)
    tokenized_data.append(tokens)  # Keep each file's tokens as a separate sequence
    print(f"MIDI file {i} tokens: {tokens[:20]} ...")

print("Number of sequences:", len(tokenized_data))
print("Sample sequence length:", len(tokenized_data[0]))

# Build vocabulary
token_to_idx, idx_to_token = build_vocab(tokenized_data)
vocab_size = len(token_to_idx)
print("Vocabulary size:", vocab_size)
print("Sample tokens:", list(token_to_idx.keys())[:10])

# Save token mappings
with open(output_dir+"token_to_idx.pkl", "wb") as f:
    pickle.dump(token_to_idx, f)
with open(output_dir+"idx_to_token.pkl", "wb") as f:
    pickle.dump(idx_to_token, f)

# Create dataset and dataloader
max_seq_length = 100  # Increased from 20 to better capture musical phrases
dataset = TokenDataset(tokenized_data, token_to_idx, max_length=max_seq_length)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)  # Increased batch size

# Initialize model and optimizer
model = MusicVAE(vocab_size, embed_size=128, hidden_size=256, latent_size=64)
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adjusted learning rate

# Train the VAE model
train_vae(model, dataloader, optimizer, epochs=20, device='cpu')  # More epochs

# Save model
torch.save(model.state_dict(), output_dir+"music_vae.pth")
print("Model saved as music_vae.pth")
# Out:
# MIDI file 0 tokens: ['TIME_SHIFT_39', 'NOTE_ON_69_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'NOTE_ON_54_96', 'TIME_SHIFT_7', 'NOTE_OFF_61', 'NOTE_ON_62_96', 'TIME_SHIFT_7', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_57_96', 'NOTE_OFF_54', 'NOTE_ON_49_96', 'TIME_SHIFT_7', 'NOTE_OFF_57', 'NOTE_ON_59_96'] ...
# MIDI file 1 tokens: ['NOTE_ON_71_96', 'NOTE_ON_64_96', 'NOTE_ON_56_96', 'NOTE_ON_50_96', 'TIME_SHIFT_25', 'NOTE_OFF_71', 'NOTE_ON_64_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_56', 'NOTE_ON_57_96', 'NOTE_OFF_50', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_64', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_68_96', 'NOTE_OFF_57', 'NOTE_ON_62_96'] ...
# MIDI file 2 tokens: ['NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'NOTE_OFF_55', 'NOTE_ON_54_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_55_96'] ...
# MIDI file 3 tokens: ['NOTE_ON_70_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'TIME_SHIFT_12', 'NOTE_OFF_70', 'NOTE_ON_72_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_62', 'NOTE_ON_60_96', 'NOTE_OFF_58', 'NOTE_ON_57_96', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_60', 'NOTE_ON_58_96'] ...
# MIDI file 4 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_58_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_66_96', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'NOTE_OFF_58', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_70_96', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_60'] ...
# MIDI file 5 tokens: ['NOTE_ON_74_96', 'NOTE_ON_69_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_69_96', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_60_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_74_96', 'NOTE_OFF_69', 'NOTE_ON_70_96', 'NOTE_OFF_64', 'NOTE_ON_65_96'] ...
# MIDI file 6 tokens: ['NOTE_ON_72_96', 'NOTE_ON_65_96', 'NOTE_ON_56_96', 'NOTE_ON_53_96', 'TIME_SHIFT_15', 'NOTE_OFF_72', 'NOTE_ON_72_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_56', 'NOTE_ON_57_96', 'NOTE_OFF_53', 'NOTE_ON_51_96', 'TIME_SHIFT_15', 'NOTE_OFF_72', 'NOTE_ON_70_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_57', 'NOTE_ON_58_96'] ...
# MIDI file 7 tokens: ['TIME_SHIFT_36', 'NOTE_ON_76_96', 'NOTE_ON_67_96', 'NOTE_ON_60_96', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_76', 'NOTE_ON_76_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_48', 'NOTE_ON_48_96', 'TIME_SHIFT_6', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'TIME_SHIFT_6', 'NOTE_OFF_76', 'NOTE_ON_72_96'] ...
# MIDI file 8 tokens: ['TIME_SHIFT_36', 'NOTE_ON_76_96', 'NOTE_ON_67_96', 'NOTE_ON_60_96', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_76', 'NOTE_ON_76_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_48', 'NOTE_ON_48_96', 'TIME_SHIFT_6', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'TIME_SHIFT_6', 'NOTE_OFF_76', 'NOTE_ON_72_96'] ...
# MIDI file 9 tokens: ['TIME_SHIFT_38', 'NOTE_ON_66_64', 'NOTE_ON_61_64', 'NOTE_ON_57_64', 'NOTE_ON_54_64', 'NOTE_ON_54_64', 'TIME_SHIFT_6', 'NOTE_OFF_54', 'NOTE_ON_52_64', 'NOTE_OFF_54', 'NOTE_ON_52_64', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_66_64', 'NOTE_OFF_61', 'NOTE_ON_62_64', 'NOTE_OFF_57', 'NOTE_ON_57_64', 'NOTE_OFF_52', 'NOTE_ON_50_64'] ...
# MIDI file 10 tokens: ['NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'TIME_SHIFT_11', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_59_96', 'NOTE_OFF_55', 'NOTE_ON_52_96', 'TIME_SHIFT_11', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_59', 'NOTE_ON_62_96'] ...
# MIDI file 11 tokens: ['TIME_SHIFT_35', 'NOTE_ON_74_96', 'NOTE_ON_65_96', 'NOTE_ON_58_96', 'NOTE_ON_46_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_70_96', 'NOTE_OFF_65', 'NOTE_ON_63_96', 'NOTE_OFF_58', 'NOTE_ON_55_96', 'NOTE_OFF_46', 'NOTE_ON_51_96', 'TIME_SHIFT_6', 'NOTE_OFF_51', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_70', 'NOTE_ON_72_96'] ...
# MIDI file 12 tokens: ['TIME_SHIFT_38', 'NOTE_ON_71_96', 'NOTE_ON_64_96', 'NOTE_ON_56_96', 'NOTE_ON_52_96', 'NOTE_ON_40_96', 'TIME_SHIFT_6', 'NOTE_OFF_56', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_68_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_52', 'NOTE_ON_52_96', 'NOTE_OFF_40', 'NOTE_ON_52_96'] ...
# MIDI file 13 tokens: ['TIME_SHIFT_34', 'NOTE_ON_69_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_50_96', 'TIME_SHIFT_11', 'NOTE_OFF_69', 'NOTE_ON_70_96', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_50', 'NOTE_ON_55_96', 'TIME_SHIFT_11', 'NOTE_OFF_70', 'NOTE_ON_72_96', 'NOTE_OFF_67', 'NOTE_ON_65_96', 'NOTE_OFF_62'] ...
# MIDI file 14 tokens: ['TIME_SHIFT_41', 'NOTE_ON_69_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_50_96', 'NOTE_ON_86_96', 'NOTE_ON_81_96', 'NOTE_ON_69_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_50_96', 'TIME_SHIFT_7', 'NOTE_OFF_86', 'NOTE_ON_84_96', 'TIME_SHIFT_7', 'NOTE_OFF_69', 'NOTE_ON_70_96', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_62'] ...
# MIDI file 15 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_55_96', 'NOTE_ON_47_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_63_96', 'NOTE_OFF_55', 'NOTE_ON_60_96', 'NOTE_OFF_47', 'NOTE_ON_48_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_48', 'NOTE_ON_48_96', 'TIME_SHIFT_6'] ...
# MIDI file 16 tokens: ['TIME_SHIFT_38', 'NOTE_ON_70_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_46_96', 'TIME_SHIFT_12', 'NOTE_OFF_70', 'NOTE_ON_69_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_62', 'NOTE_ON_60_96', 'NOTE_OFF_46', 'NOTE_ON_53_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_67_96', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_60'] ...
# MIDI file 17 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_63_96', 'NOTE_OFF_58', 'NOTE_ON_57_96', 'NOTE_OFF_55', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_66_96', 'NOTE_OFF_63', 'NOTE_ON_62_96', 'NOTE_OFF_57'] ...
# MIDI file 18 tokens: ['TIME_SHIFT_36', 'NOTE_ON_65_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_53_96', 'NOTE_ON_65_96', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_53', 'NOTE_ON_52_96', 'NOTE_OFF_57', 'NOTE_ON_60_96', 'TIME_SHIFT_6', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_57_96', 'NOTE_OFF_52'] ...
# MIDI file 19 tokens: ['NOTE_ON_74_96', 'NOTE_ON_65_96', 'NOTE_ON_58_96', 'NOTE_ON_58_96', 'TIME_SHIFT_6', 'NOTE_OFF_58', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_74', 'NOTE_ON_75_96', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'NOTE_OFF_58', 'NOTE_ON_58_96', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'TIME_SHIFT_6'] ...
# MIDI file 20 tokens: ['TIME_SHIFT_12', 'NOTE_ON_72_96', 'NOTE_ON_63_96', 'NOTE_ON_55_96', 'NOTE_ON_48_96', 'NOTE_ON_48_96', 'TIME_SHIFT_25', 'NOTE_OFF_72', 'NOTE_ON_67_96', 'NOTE_OFF_63', 'NOTE_ON_62_96', 'NOTE_OFF_55', 'NOTE_ON_58_96', 'NOTE_OFF_48', 'NOTE_ON_46_96', 'NOTE_OFF_48', 'NOTE_ON_46_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_72_96'] ...
# MIDI file 21 tokens: ['NOTE_ON_70_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'TIME_SHIFT_12', 'NOTE_OFF_70', 'NOTE_ON_70_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_58', 'NOTE_ON_58_96', 'TIME_SHIFT_12', 'NOTE_OFF_70', 'NOTE_ON_77_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_62', 'NOTE_ON_60_96'] ...
# MIDI file 22 tokens: ['TIME_SHIFT_35', 'NOTE_ON_74_96', 'NOTE_ON_67_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_74_96', 'NOTE_ON_71_96', 'NOTE_ON_67_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_76_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_48_96', 'NOTE_OFF_74', 'NOTE_ON_76_96', 'NOTE_OFF_71'] ...
# MIDI file 23 tokens: ['NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'TIME_SHIFT_27', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_61', 'NOTE_ON_59_96', 'NOTE_OFF_57', 'NOTE_ON_56_96', 'TIME_SHIFT_14', 'NOTE_OFF_71', 'NOTE_ON_73_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'NOTE_OFF_59', 'NOTE_ON_66_96'] ...
# MIDI file 24 tokens: ['NOTE_ON_50_96', 'NOTE_ON_50_96', 'TIME_SHIFT_8', 'NOTE_ON_62_96', 'NOTE_ON_54_96', 'TIME_SHIFT_4', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_54', 'NOTE_ON_55_96', 'TIME_SHIFT_4', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_4', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_57', 'NOTE_ON_59_96'] ...
# MIDI file 25 tokens: ['NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'NOTE_OFF_60', 'NOTE_ON_59_96', 'NOTE_OFF_55', 'NOTE_ON_53_96', 'NOTE_OFF_55'] ...
# MIDI file 26 tokens: ['NOTE_ON_71_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_59_96', 'TIME_SHIFT_6', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_66', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'NOTE_OFF_57'] ...
# MIDI file 27 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_59_96', 'NOTE_OFF_55', 'NOTE_ON_52_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_59'] ...
# MIDI file 28 tokens: ['TIME_SHIFT_36', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_57_96', 'NOTE_ON_49_96', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_57', 'NOTE_ON_45_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_66_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_57_96', 'NOTE_OFF_49', 'NOTE_ON_50_96', 'NOTE_OFF_45', 'NOTE_ON_38_96'] ...
# MIDI file 29 tokens: ['NOTE_ON_71_96', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_52', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'NOTE_OFF_54', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_66_96', 'TIME_SHIFT_6'] ...
# MIDI file 30 tokens: ['TIME_SHIFT_25', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_45_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_45', 'NOTE_ON_57_96', 'TIME_SHIFT_12', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_69_96'] ...
# MIDI file 31 tokens: ['TIME_SHIFT_38', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_45_96', 'TIME_SHIFT_12', 'NOTE_OFF_64', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_45', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96'] ...
# MIDI file 32 tokens: ['TIME_SHIFT_38', 'NOTE_ON_73_96', 'NOTE_ON_64_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_73', 'NOTE_ON_71_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_57', 'NOTE_ON_56_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_59', 'NOTE_ON_61_96', 'NOTE_OFF_56'] ...
# MIDI file 33 tokens: ['TIME_SHIFT_20', 'NOTE_ON_66_96', 'NOTE_ON_61_96', 'NOTE_ON_58_96', 'NOTE_ON_54_96', 'TIME_SHIFT_10', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_61', 'NOTE_ON_63_96', 'NOTE_OFF_58', 'NOTE_ON_59_96', 'NOTE_OFF_54', 'NOTE_ON_59_96', 'TIME_SHIFT_10', 'NOTE_OFF_59', 'NOTE_ON_58_96', 'TIME_SHIFT_10', 'NOTE_OFF_66', 'NOTE_ON_66_96'] ...
# MIDI file 34 tokens: ['TIME_SHIFT_41', 'NOTE_ON_73_96', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_45_96', 'TIME_SHIFT_14', 'NOTE_OFF_73', 'NOTE_ON_69_96', 'NOTE_OFF_69', 'NOTE_ON_66_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'NOTE_OFF_45', 'NOTE_ON_50_96', 'TIME_SHIFT_7', 'NOTE_OFF_50', 'NOTE_ON_49_96', 'TIME_SHIFT_7', 'NOTE_OFF_69', 'NOTE_ON_71_96'] ...
# MIDI file 35 tokens: ['TIME_SHIFT_38', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_43_96', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_62_96', 'NOTE_OFF_55', 'NOTE_ON_59_96', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'NOTE_OFF_55', 'NOTE_ON_59_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_69_96'] ...
# MIDI file 36 tokens: ['TIME_SHIFT_38', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_43_96', 'TIME_SHIFT_6', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'TIME_SHIFT_12'] ...
# MIDI file 37 tokens: ['TIME_SHIFT_38', 'NOTE_ON_73_96', 'NOTE_ON_66_96', 'NOTE_ON_58_96', 'NOTE_ON_54_96', 'TIME_SHIFT_12', 'NOTE_OFF_73', 'NOTE_ON_74_96', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_58', 'NOTE_ON_59_96', 'NOTE_OFF_54', 'NOTE_ON_47_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_73_96', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_59'] ...
# MIDI file 38 tokens: ['NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_43_96', 'TIME_SHIFT_8', 'NOTE_OFF_43', 'NOTE_ON_47_96', 'TIME_SHIFT_8', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_59', 'NOTE_ON_54_96', 'NOTE_OFF_47', 'NOTE_ON_50_96', 'TIME_SHIFT_8', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_62'] ...
# MIDI file 39 tokens: ['NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_60_96', 'NOTE_ON_79_96', 'NOTE_ON_76_96', 'NOTE_ON_72_96', 'TIME_SHIFT_7', 'NOTE_OFF_60', 'NOTE_ON_58_96', 'TIME_SHIFT_7', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_58', 'NOTE_ON_57_96', 'NOTE_OFF_79'] ...
# MIDI file 40 tokens: ['NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_60_96', 'TIME_SHIFT_7', 'NOTE_OFF_60', 'NOTE_ON_58_96', 'TIME_SHIFT_7', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_58', 'NOTE_ON_57_96', 'TIME_SHIFT_7', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'TIME_SHIFT_7'] ...
# MIDI file 41 tokens: ['TIME_SHIFT_38', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_64', 'NOTE_ON_65_96', 'TIME_SHIFT_6', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'NOTE_OFF_57', 'NOTE_ON_52_96', 'NOTE_OFF_57', 'NOTE_ON_52_96'] ...
# MIDI file 42 tokens: ['TIME_SHIFT_35', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_45_96', 'TIME_SHIFT_12', 'NOTE_OFF_64', 'NOTE_ON_69_96', 'NOTE_OFF_60', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_60_96', 'NOTE_OFF_45', 'NOTE_ON_57_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_60'] ...
# MIDI file 43 tokens: ['TIME_SHIFT_35', 'NOTE_ON_67_96', 'NOTE_ON_63_96', 'NOTE_ON_60_96', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_72_96', 'NOTE_OFF_63', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_63_96', 'NOTE_OFF_48', 'NOTE_ON_60_96', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_63'] ...
# MIDI file 44 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_45_96', 'TIME_SHIFT_6', 'NOTE_OFF_64', 'NOTE_ON_65_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_60_96', 'NOTE_OFF_45', 'NOTE_ON_57_96', 'TIME_SHIFT_6'] ...
# MIDI file 45 tokens: ['NOTE_ON_43_96', 'TIME_SHIFT_8', 'NOTE_ON_62_96', 'TIME_SHIFT_8', 'NOTE_OFF_43', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'TIME_SHIFT_8', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'TIME_SHIFT_8', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'TIME_SHIFT_4', 'NOTE_OFF_71', 'NOTE_ON_69_96', 'TIME_SHIFT_4', 'NOTE_ON_50_96', 'NOTE_OFF_69', 'NOTE_ON_67_96'] ...
# MIDI file 46 tokens: ['NOTE_ON_43_96', 'TIME_SHIFT_8', 'NOTE_ON_62_96', 'TIME_SHIFT_8', 'NOTE_OFF_43', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'TIME_SHIFT_8', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'TIME_SHIFT_8', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'TIME_SHIFT_4', 'NOTE_OFF_71', 'NOTE_ON_69_96', 'TIME_SHIFT_4', 'NOTE_ON_50_96', 'NOTE_OFF_69', 'NOTE_ON_67_96'] ...
# MIDI file 47 tokens: ['TIME_SHIFT_50', 'NOTE_ON_80_96', 'NOTE_ON_76_96', 'NOTE_ON_64_96', 'NOTE_ON_71_96', 'TIME_SHIFT_8', 'NOTE_OFF_80', 'NOTE_ON_83_96', 'NOTE_OFF_64', 'NOTE_ON_68_96', 'NOTE_OFF_71', 'NOTE_ON_72_96', 'TIME_SHIFT_4', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'TIME_SHIFT_4', 'NOTE_OFF_76', 'NOTE_ON_76_96', 'NOTE_OFF_68', 'NOTE_ON_69_96'] ...
# MIDI file 48 tokens: ['TIME_SHIFT_50', 'NOTE_ON_80_96', 'NOTE_ON_76_96', 'NOTE_ON_64_96', 'NOTE_ON_71_96', 'TIME_SHIFT_8', 'NOTE_OFF_80', 'NOTE_ON_83_96', 'NOTE_OFF_64', 'NOTE_ON_68_96', 'NOTE_OFF_71', 'NOTE_ON_72_96', 'TIME_SHIFT_4', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'TIME_SHIFT_4', 'NOTE_OFF_76', 'NOTE_ON_76_96', 'NOTE_OFF_68', 'NOTE_ON_69_96'] ...
# MIDI file 49 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_70_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_61', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'TIME_SHIFT_6', 'NOTE_OFF_70', 'NOTE_ON_69_96'] ...
# MIDI file 50 tokens: ['NOTE_ON_74_96', 'NOTE_ON_67_96', 'NOTE_ON_58_96', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_58_96', 'TIME_SHIFT_12', 'NOTE_OFF_74'] ...
# MIDI file 51 tokens: ['NOTE_ON_74_96', 'NOTE_ON_67_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_59_96', 'NOTE_OFF_55', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_59', 'NOTE_ON_62_96', 'TIME_SHIFT_6', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_67'] ...
# MIDI file 52 tokens: ['NOTE_ON_55_96', 'NOTE_ON_71_96', 'NOTE_ON_67_96', 'TIME_SHIFT_6', 'NOTE_ON_43_96', 'TIME_SHIFT_6', 'NOTE_OFF_55', 'NOTE_OFF_43', 'NOTE_ON_43_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_72_96', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_43', 'NOTE_ON_43_96', 'TIME_SHIFT_6', 'NOTE_ON_74_96', 'NOTE_ON_67_96', 'NOTE_ON_59_96'] ...
# MIDI file 53 tokens: ['TIME_SHIFT_19', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_74_96', 'NOTE_ON_71_96', 'TIME_SHIFT_9', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_59_96', 'NOTE_OFF_55', 'NOTE_ON_52_96', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_71', 'NOTE_ON_71_96'] ...
# MIDI file 54 tokens: ['TIME_SHIFT_38', 'NOTE_ON_74_96', 'NOTE_ON_69_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'TIME_SHIFT_6', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'NOTE_OFF_61', 'NOTE_ON_59_96', 'TIME_SHIFT_6'] ...
# MIDI file 55 tokens: ['NOTE_ON_71_96', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_52_96', 'TIME_SHIFT_13', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_67', 'NOTE_ON_66_96', 'NOTE_OFF_64', 'NOTE_ON_59_96', 'NOTE_OFF_52', 'NOTE_ON_50_96', 'TIME_SHIFT_13', 'NOTE_OFF_71', 'NOTE_ON_69_96', 'NOTE_OFF_66', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_60_96'] ...
# MIDI file 56 tokens: ['TIME_SHIFT_38', 'NOTE_ON_62_96', 'NOTE_ON_57_96', 'NOTE_ON_53_96', 'NOTE_ON_50_96', 'TIME_SHIFT_12', 'NOTE_OFF_62', 'NOTE_ON_69_96', 'NOTE_OFF_57', 'NOTE_ON_64_96', 'NOTE_OFF_53', 'NOTE_ON_57_96', 'NOTE_OFF_50', 'NOTE_ON_49_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_65_96', 'NOTE_OFF_57'] ...
# MIDI file 57 tokens: ['TIME_SHIFT_38', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_47_96', 'TIME_SHIFT_6', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_61_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_61', 'NOTE_ON_62_96', 'NOTE_OFF_47', 'NOTE_ON_59_96', 'TIME_SHIFT_12'] ...
# MIDI file 58 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_63_96', 'NOTE_ON_60_96', 'NOTE_ON_48_96', 'TIME_SHIFT_6', 'NOTE_OFF_63', 'NOTE_ON_65_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_72_96', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_48', 'NOTE_ON_51_96', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_71_96'] ...
# MIDI file 59 tokens: ['TIME_SHIFT_38', 'NOTE_ON_71_96', 'NOTE_ON_68_96', 'NOTE_ON_64_96', 'NOTE_ON_52_96', 'TIME_SHIFT_12', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_68', 'NOTE_ON_66_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_52', 'NOTE_ON_51_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_68_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_71_96'] ...
# MIDI file 60 tokens: ['NOTE_ON_69_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_50', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_52', 'NOTE_ON_53_96', 'TIME_SHIFT_6', 'NOTE_OFF_53', 'NOTE_ON_50_96', 'TIME_SHIFT_6'] ...
# MIDI file 61 tokens: ['TIME_SHIFT_36', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_47_96', 'TIME_SHIFT_6', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_61_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_61', 'NOTE_ON_62_96', 'NOTE_OFF_47', 'NOTE_ON_59_96', 'TIME_SHIFT_12'] ...
# MIDI file 62 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_43_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_58', 'NOTE_ON_58_96', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_58'] ...
# MIDI file 63 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_50_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_57_96', 'NOTE_OFF_50', 'NOTE_ON_49_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_65_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'NOTE_OFF_57'] ...
# MIDI file 64 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_67_96', 'NOTE_ON_59_96', 'NOTE_ON_43_96', 'TIME_SHIFT_6', 'NOTE_OFF_55', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'NOTE_OFF_54', 'NOTE_ON_52_96'] ...
# MIDI file 65 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_55', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'NOTE_OFF_54', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_52', 'NOTE_ON_54_96'] ...
# MIDI file 66 tokens: ['TIME_SHIFT_47', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_59_96', 'NOTE_ON_59_96', 'TIME_SHIFT_8', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'TIME_SHIFT_8', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'NOTE_OFF_59', 'NOTE_ON_54_96'] ...
# MIDI file 67 tokens: ['TIME_SHIFT_41', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_59_96', 'TIME_SHIFT_7', 'NOTE_OFF_66', 'NOTE_ON_68_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'TIME_SHIFT_7', 'NOTE_OFF_68', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_59', 'NOTE_ON_61_96', 'NOTE_OFF_59', 'NOTE_ON_54_96', 'TIME_SHIFT_14'] ...
# MIDI file 68 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_63_96', 'NOTE_ON_60_96', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_72_96', 'NOTE_OFF_63', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_63_96', 'NOTE_OFF_48', 'NOTE_ON_60_96', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_63'] ...
# MIDI file 69 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_57_96', 'NOTE_ON_49_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_66_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_57_96', 'NOTE_OFF_49', 'NOTE_ON_50_96', 'TIME_SHIFT_12', 'NOTE_OFF_66', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'NOTE_OFF_57'] ...
# MIDI file 70 tokens: ['TIME_SHIFT_36', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_43_96', 'NOTE_ON_74_96', 'TIME_SHIFT_6', 'NOTE_OFF_43', 'NOTE_ON_45_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_62_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_59', 'NOTE_ON_59_96', 'NOTE_OFF_45', 'NOTE_ON_47_96', 'NOTE_OFF_74', 'NOTE_ON_79_96'] ...
# MIDI file 71 tokens: ['TIME_SHIFT_38', 'NOTE_ON_65_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_53_96', 'TIME_SHIFT_12', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_58_96', 'NOTE_OFF_53', 'NOTE_ON_46_96', 'TIME_SHIFT_6', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'TIME_SHIFT_6'] ...
# MIDI file 72 tokens: ['TIME_SHIFT_38', 'NOTE_ON_74_96', 'NOTE_ON_70_96', 'NOTE_ON_65_96', 'NOTE_ON_46_96', 'NOTE_ON_70_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'TIME_SHIFT_6', 'NOTE_OFF_70', 'NOTE_ON_72_96', 'NOTE_OFF_62', 'NOTE_ON_63_96', 'TIME_SHIFT_6', 'NOTE_OFF_74', 'NOTE_ON_70_96', 'NOTE_OFF_70', 'NOTE_ON_65_96', 'NOTE_OFF_65', 'NOTE_ON_62_96'] ...
# MIDI file 73 tokens: ['TIME_SHIFT_38', 'NOTE_ON_74_96', 'NOTE_ON_70_96', 'NOTE_ON_65_96', 'NOTE_ON_46_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_70_96', 'NOTE_OFF_70', 'NOTE_ON_65_96', 'NOTE_OFF_65', 'NOTE_ON_62_96', 'NOTE_OFF_46', 'NOTE_ON_58_96', 'TIME_SHIFT_12', 'NOTE_OFF_70', 'NOTE_ON_72_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_62'] ...
# MIDI file 74 tokens: ['NOTE_ON_46_96', 'NOTE_ON_74_96', 'NOTE_ON_70_96', 'NOTE_ON_65_96', 'TIME_SHIFT_8', 'NOTE_OFF_46', 'NOTE_ON_45_96', 'TIME_SHIFT_8', 'NOTE_OFF_45', 'NOTE_ON_46_96', 'NOTE_OFF_70', 'NOTE_ON_65_96', 'NOTE_OFF_65', 'NOTE_ON_62_96', 'TIME_SHIFT_4', 'NOTE_OFF_74', 'NOTE_ON_72_96', 'TIME_SHIFT_4', 'NOTE_OFF_46', 'NOTE_ON_48_96'] ...
# MIDI file 75 tokens: ['TIME_SHIFT_38', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_43_96', 'TIME_SHIFT_6', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'TIME_SHIFT_12'] ...
# MIDI file 76 tokens: ['NOTE_ON_79_96', 'NOTE_ON_79_96', 'NOTE_ON_79_96', 'NOTE_ON_74_96', 'NOTE_ON_71_96', 'NOTE_ON_43_96', 'NOTE_ON_43_96', 'TIME_SHIFT_8', 'NOTE_ON_62_96', 'TIME_SHIFT_8', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_79', 'NOTE_OFF_79', 'NOTE_OFF_79', 'NOTE_OFF_74', 'NOTE_OFF_71', 'NOTE_OFF_43', 'NOTE_OFF_43', 'TIME_SHIFT_8'] ...
# MIDI file 77 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_50_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_57_96', 'NOTE_OFF_50', 'NOTE_ON_49_96', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_57_96'] ...
# MIDI file 78 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_50_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_57_96', 'NOTE_OFF_50', 'NOTE_ON_49_96', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_57_96'] ...
# MIDI file 79 tokens: ['TIME_SHIFT_35', 'NOTE_ON_67_96', 'NOTE_ON_63_96', 'NOTE_ON_60_96', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_63', 'NOTE_ON_62_96', 'NOTE_OFF_60', 'NOTE_ON_55_96', 'NOTE_OFF_48', 'NOTE_ON_47_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_63_96', 'NOTE_OFF_62', 'NOTE_ON_60_96', 'NOTE_OFF_55'] ...
# MIDI file 80 tokens: ['TIME_SHIFT_38', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_59_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'NOTE_OFF_59', 'NOTE_ON_54_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_71_96'] ...
# MIDI file 81 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_43_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'TIME_SHIFT_6'] ...
# MIDI file 82 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_61_96', 'NOTE_ON_45_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_61', 'NOTE_ON_62_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_73_96', 'NOTE_OFF_64', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_45', 'NOTE_ON_57_96', 'TIME_SHIFT_6'] ...
# MIDI file 83 tokens: ['NOTE_ON_74_96', 'NOTE_ON_65_96', 'NOTE_ON_58_96', 'NOTE_ON_58_96', 'NOTE_ON_58_96', 'NOTE_ON_74_96', 'NOTE_ON_70_96', 'NOTE_ON_65_96', 'TIME_SHIFT_4', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_70', 'NOTE_ON_70_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'TIME_SHIFT_4', 'NOTE_OFF_65', 'NOTE_ON_70_96', 'NOTE_OFF_58', 'NOTE_ON_60_96'] ...
# MIDI file 84 tokens: ['NOTE_ON_53_96', 'TIME_SHIFT_17', 'NOTE_ON_69_96', 'NOTE_OFF_53', 'TIME_SHIFT_9', 'NOTE_OFF_69', 'NOTE_ON_65_96', 'TIME_SHIFT_9', 'NOTE_OFF_65', 'NOTE_ON_72_96', 'TIME_SHIFT_17', 'NOTE_OFF_72', 'NOTE_ON_72_96', 'NOTE_ON_72_96', 'NOTE_ON_65_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'TIME_SHIFT_9', 'NOTE_OFF_72', 'NOTE_ON_77_96'] ...
# MIDI file 85 tokens: ['TIME_SHIFT_31', 'NOTE_ON_59_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'TIME_SHIFT_6', 'NOTE_OFF_59', 'NOTE_ON_50_96', 'NOTE_OFF_66', 'NOTE_ON_71_96', 'NOTE_OFF_62', 'NOTE_ON_66_96', 'NOTE_OFF_59', 'NOTE_ON_59_96', 'TIME_SHIFT_9', 'NOTE_OFF_71', 'NOTE_ON_74_96', 'TIME_SHIFT_3', 'NOTE_OFF_50', 'NOTE_ON_52_96'] ...
# MIDI file 86 tokens: ['TIME_SHIFT_43', 'NOTE_ON_71_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_47_96', 'TIME_SHIFT_14', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_47', 'NOTE_ON_52_96', 'TIME_SHIFT_7', 'NOTE_OFF_52', 'NOTE_ON_54_96', 'TIME_SHIFT_7', 'NOTE_OFF_71', 'NOTE_ON_71_96'] ...
# MIDI file 87 tokens: ['TIME_SHIFT_38', 'NOTE_ON_71_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_47_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_73_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'TIME_SHIFT_6', 'NOTE_OFF_73', 'NOTE_ON_74_96', 'NOTE_OFF_66', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_47', 'NOTE_ON_59_96', 'TIME_SHIFT_12'] ...
# MIDI file 88 tokens: ['TIME_SHIFT_38', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'TIME_SHIFT_12', 'NOTE_OFF_64', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'NOTE_OFF_57', 'NOTE_ON_52_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_55'] ...
# MIDI file 89 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_43_96', 'NOTE_ON_67_96', 'NOTE_ON_59_96', 'NOTE_ON_67_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_66_96', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_59', 'NOTE_ON_62_96', 'NOTE_OFF_67'] ...
# MIDI file 90 tokens: ['TIME_SHIFT_38', 'NOTE_ON_71_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'TIME_SHIFT_6', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_66', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_61', 'NOTE_ON_59_96'] ...
# MIDI file 91 tokens: ['TIME_SHIFT_40', 'NOTE_ON_70_96', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_55_96', 'TIME_SHIFT_13', 'NOTE_OFF_70', 'NOTE_ON_70_96', 'NOTE_OFF_67', 'NOTE_ON_65_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_55', 'NOTE_ON_50_96', 'TIME_SHIFT_7', 'NOTE_OFF_62', 'NOTE_ON_60_96', 'TIME_SHIFT_7', 'NOTE_OFF_70', 'NOTE_ON_67_96'] ...
# MIDI file 92 tokens: ['NOTE_ON_67_96', 'NOTE_ON_63_96', 'NOTE_ON_58_96', 'NOTE_ON_51_96', 'NOTE_ON_51_96', 'TIME_SHIFT_6', 'NOTE_OFF_51', 'NOTE_ON_50_96', 'NOTE_OFF_51', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_68_96', 'NOTE_OFF_63', 'NOTE_ON_63_96', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'NOTE_OFF_50', 'NOTE_ON_48_96', 'NOTE_OFF_50'] ...
# MIDI file 93 tokens: ['NOTE_ON_71_96', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_55_96', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_55', 'NOTE_ON_54_96', 'NOTE_OFF_55', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_72_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_54', 'NOTE_ON_52_96', 'NOTE_OFF_54'] ...
# MIDI file 94 tokens: ['TIME_SHIFT_38', 'NOTE_ON_73_96', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_45_96', 'TIME_SHIFT_6', 'NOTE_OFF_73', 'NOTE_ON_71_96', 'NOTE_OFF_69', 'NOTE_ON_68_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_69_96', 'NOTE_OFF_68', 'NOTE_ON_66_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_45', 'NOTE_ON_50_96', 'TIME_SHIFT_6'] ...
# MIDI file 95 tokens: ['TIME_SHIFT_39', 'NOTE_ON_74_96', 'NOTE_ON_69_96', 'NOTE_ON_62_96', 'NOTE_ON_54_96', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_62', 'NOTE_ON_60_96', 'TIME_SHIFT_6', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_69', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_59_96', 'NOTE_OFF_54', 'NOTE_ON_55_96', 'NOTE_OFF_54', 'NOTE_ON_55_96'] ...
# MIDI file 96 tokens: ['TIME_SHIFT_39', 'NOTE_ON_74_96', 'NOTE_ON_67_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'TIME_SHIFT_6', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_55', 'NOTE_ON_47_96', 'NOTE_OFF_55', 'NOTE_ON_47_96'] ...
# MIDI file 97 tokens: ['TIME_SHIFT_39', 'NOTE_ON_74_96', 'NOTE_ON_67_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_55_96', 'TIME_SHIFT_13', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'NOTE_OFF_55', 'NOTE_ON_54_96', 'NOTE_OFF_55', 'NOTE_ON_54_96', 'TIME_SHIFT_13', 'NOTE_OFF_74', 'NOTE_ON_74_96'] ...
# MIDI file 98 tokens: ['TIME_SHIFT_20', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_59_96', 'NOTE_ON_52_96', 'TIME_SHIFT_20', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'NOTE_OFF_52', 'NOTE_ON_53_96', 'TIME_SHIFT_10', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'TIME_SHIFT_10', 'NOTE_OFF_69', 'NOTE_ON_72_96'] ...
# MIDI file 99 tokens: ['TIME_SHIFT_38', 'NOTE_ON_71_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'TIME_SHIFT_12', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_62', 'NOTE_ON_63_96', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'TIME_SHIFT_12', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_66', 'NOTE_ON_68_96', 'NOTE_OFF_63'] ...
# MIDI file 100 tokens: ['NOTE_ON_74_96', 'NOTE_ON_69_96', 'NOTE_ON_66_96', 'NOTE_ON_50_96', 'NOTE_ON_50_96', 'NOTE_ON_81_96', 'NOTE_ON_78_96', 'NOTE_ON_74_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_50', 'NOTE_ON_62_96', 'NOTE_OFF_50', 'NOTE_ON_50_96', 'NOTE_OFF_81'] ...
# MIDI file 101 tokens: ['TIME_SHIFT_38', 'NOTE_ON_64_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_52_96', 'NOTE_ON_40_96', 'TIME_SHIFT_6', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_52', 'NOTE_ON_52_96'] ...
# MIDI file 102 tokens: ['NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_55_96', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_58', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_58_96', 'NOTE_OFF_57'] ...
# MIDI file 103 tokens: ['NOTE_ON_74_96', 'NOTE_ON_66_96', 'NOTE_ON_59_96', 'NOTE_ON_47_96', 'TIME_SHIFT_15', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_59', 'NOTE_ON_59_96', 'NOTE_OFF_47', 'NOTE_ON_59_96', 'TIME_SHIFT_8', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'TIME_SHIFT_8', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_66'] ...
# MIDI file 104 tokens: ['NOTE_ON_71_96', 'NOTE_ON_68_96', 'NOTE_ON_64_96', 'NOTE_ON_52_96', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_52', 'NOTE_ON_54_96', 'NOTE_OFF_52', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_68', 'NOTE_ON_68_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_54', 'NOTE_ON_56_96', 'NOTE_OFF_54'] ...
# MIDI file 105 tokens: ['TIME_SHIFT_38', 'NOTE_ON_64_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'NOTE_OFF_52', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_64', 'NOTE_ON_71_96', 'NOTE_OFF_59', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_54', 'NOTE_ON_55_96', 'TIME_SHIFT_6'] ...
# MIDI file 106 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_55_96', 'TIME_SHIFT_13', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_63_96', 'NOTE_OFF_58', 'NOTE_ON_58_96', 'NOTE_OFF_55', 'NOTE_ON_48_96', 'TIME_SHIFT_6', 'NOTE_OFF_63', 'NOTE_ON_62_96', 'NOTE_OFF_48', 'NOTE_ON_50_96', 'TIME_SHIFT_6'] ...
# MIDI file 107 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'TIME_SHIFT_13', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_65_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_57', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_50', 'NOTE_ON_52_96', 'TIME_SHIFT_6'] ...
# MIDI file 108 tokens: ['TIME_SHIFT_40', 'NOTE_ON_77_96', 'NOTE_ON_69_96', 'NOTE_ON_60_96', 'NOTE_ON_53_96', 'TIME_SHIFT_7', 'NOTE_OFF_53', 'NOTE_ON_55_96', 'TIME_SHIFT_7', 'NOTE_OFF_77', 'NOTE_ON_77_96', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_13', 'NOTE_OFF_77', 'NOTE_ON_77_96'] ...
# MIDI file 109 tokens: ['TIME_SHIFT_38', 'NOTE_ON_74_96', 'NOTE_ON_69_96', 'NOTE_ON_62_96', 'NOTE_ON_54_96', 'NOTE_ON_74_96', 'NOTE_ON_69_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_71_96', 'NOTE_OFF_69', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_54', 'NOTE_ON_55_96', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_69', 'NOTE_ON_71_96'] ...
# MIDI file 110 tokens: ['TIME_SHIFT_70', 'NOTE_ON_62_96', 'NOTE_ON_69_96', 'TIME_SHIFT_10', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_69', 'NOTE_ON_74_96', 'TIME_SHIFT_5', 'NOTE_OFF_74', 'NOTE_ON_76_96', 'TIME_SHIFT_5', 'NOTE_OFF_76', 'NOTE_ON_78_96', 'TIME_SHIFT_10', 'NOTE_OFF_62', 'NOTE_ON_57_96', 'NOTE_OFF_78', 'NOTE_ON_78_96', 'TIME_SHIFT_10'] ...
# MIDI file 111 tokens: ['TIME_SHIFT_22', 'NOTE_ON_72_96', 'NOTE_ON_67_96', 'NOTE_ON_60_96', 'NOTE_ON_48_96', 'NOTE_ON_48_96', 'NOTE_ON_60_96', 'TIME_SHIFT_6', 'NOTE_OFF_48', 'NOTE_ON_47_96', 'TIME_SHIFT_6', 'NOTE_OFF_72', 'NOTE_ON_72_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_64_96', 'NOTE_OFF_48', 'NOTE_ON_48_96', 'NOTE_OFF_47'] ...
# MIDI file 112 tokens: ['TIME_SHIFT_38', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_57_96', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'NOTE_OFF_50', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_61', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_57_96', 'NOTE_OFF_52'] ...
# MIDI file 113 tokens: ['TIME_SHIFT_38', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_45_96', 'TIME_SHIFT_6', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_45', 'NOTE_ON_47_96', 'TIME_SHIFT_6', 'NOTE_OFF_64', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_57_96', 'NOTE_OFF_47', 'NOTE_ON_48_96', 'TIME_SHIFT_6'] ...
# MIDI file 114 tokens: ['TIME_SHIFT_41', 'NOTE_ON_71_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_83_96', 'NOTE_ON_47_96', 'TIME_SHIFT_7', 'NOTE_OFF_83', 'NOTE_ON_81_96', 'TIME_SHIFT_7', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_64_96', 'NOTE_OFF_81'] ...
# MIDI file 115 tokens: ['NOTE_ON_48_96', 'NOTE_ON_48_96', 'NOTE_ON_76_96', 'NOTE_ON_72_96', 'NOTE_ON_67_96', 'TIME_SHIFT_8', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'TIME_SHIFT_8', 'NOTE_OFF_48', 'NOTE_OFF_48', 'NOTE_OFF_76', 'NOTE_OFF_72', 'NOTE_OFF_67', 'NOTE_OFF_67', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_60_96', 'NOTE_ON_60_96'] ...
# MIDI file 116 tokens: ['NOTE_ON_67_96', 'NOTE_ON_55_96', 'TIME_SHIFT_4', 'NOTE_OFF_67', 'NOTE_ON_71_96', 'TIME_SHIFT_4', 'NOTE_OFF_71', 'NOTE_ON_74_96', 'TIME_SHIFT_4', 'NOTE_OFF_74', 'NOTE_ON_71_96', 'TIME_SHIFT_4', 'NOTE_OFF_71', 'NOTE_ON_67_96', 'NOTE_OFF_55', 'TIME_SHIFT_4', 'NOTE_OFF_67', 'NOTE_ON_66_96', 'TIME_SHIFT_4', 'NOTE_OFF_66'] ...
# MIDI file 117 tokens: ['NOTE_ON_76_96', 'NOTE_ON_52_96', 'TIME_SHIFT_7', 'NOTE_OFF_76', 'NOTE_ON_71_96', 'TIME_SHIFT_7', 'NOTE_OFF_71', 'NOTE_ON_76_96', 'NOTE_OFF_52', 'NOTE_ON_55_96', 'TIME_SHIFT_7', 'NOTE_OFF_76', 'NOTE_ON_79_96', 'TIME_SHIFT_7', 'NOTE_OFF_79', 'NOTE_ON_83_96', 'NOTE_OFF_55', 'NOTE_ON_51_96', 'TIME_SHIFT_7', 'NOTE_OFF_83'] ...
# MIDI file 118 tokens: ['NOTE_ON_72_96', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_48_96', 'NOTE_ON_48_96', 'NOTE_ON_79_96', 'NOTE_ON_76_96', 'NOTE_ON_72_96', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_72_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_48', 'NOTE_ON_60_96', 'NOTE_OFF_48', 'NOTE_ON_48_96', 'NOTE_OFF_79'] ...
# MIDI file 119 tokens: ['NOTE_ON_72_110', 'NOTE_ON_67_110', 'NOTE_ON_64_110', 'NOTE_ON_48_110', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_72_110', 'NOTE_OFF_67', 'NOTE_ON_67_110', 'NOTE_OFF_64', 'NOTE_ON_64_110', 'NOTE_OFF_48', 'NOTE_ON_60_110', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_79_110', 'NOTE_OFF_67', 'NOTE_ON_67_110', 'NOTE_OFF_64', 'NOTE_ON_62_110'] ...
# MIDI file 120 tokens: ['NOTE_ON_59_96', 'NOTE_ON_78_96', 'NOTE_ON_74_96', 'NOTE_ON_74_96', 'NOTE_ON_74_96', 'NOTE_ON_66_96', 'TIME_SHIFT_10', 'NOTE_OFF_59', 'NOTE_ON_47_96', 'NOTE_OFF_78', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_ON_71_96', 'NOTE_OFF_74', 'NOTE_OFF_74', 'NOTE_ON_83_96', 'NOTE_ON_83_96', 'NOTE_OFF_66', 'NOTE_ON_74_96', 'TIME_SHIFT_5'] ...
# MIDI file 121 tokens: ['TIME_SHIFT_37', 'NOTE_ON_64_96', 'NOTE_ON_59_96', 'NOTE_ON_56_96', 'NOTE_ON_40_96', 'TIME_SHIFT_6', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_56', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_68_96', 'NOTE_OFF_59', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_40', 'NOTE_ON_52_96', 'TIME_SHIFT_12'] ...
# MIDI file 122 tokens: ['NOTE_ON_51_96', 'NOTE_ON_63_96', 'NOTE_ON_58_96', 'NOTE_ON_55_96', 'TIME_SHIFT_7', 'NOTE_OFF_51', 'TIME_SHIFT_3', 'NOTE_OFF_63', 'NOTE_OFF_58', 'NOTE_ON_63_96', 'NOTE_ON_58_96', 'NOTE_OFF_55', 'NOTE_ON_55_96', 'TIME_SHIFT_3', 'NOTE_ON_63_96', 'NOTE_OFF_63', 'NOTE_OFF_58', 'NOTE_ON_63_96', 'NOTE_ON_58_96', 'NOTE_OFF_55'] ...
# MIDI file 123 tokens: ['TIME_SHIFT_55', 'NOTE_ON_58_96', 'TIME_SHIFT_8', 'NOTE_OFF_58', 'NOTE_ON_63_96', 'NOTE_ON_39_96', 'NOTE_ON_27_96', 'TIME_SHIFT_4', 'NOTE_OFF_63', 'NOTE_ON_65_96', 'TIME_SHIFT_4', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'TIME_SHIFT_8', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_39', 'NOTE_ON_39_96', 'NOTE_OFF_27', 'NOTE_ON_27_96'] ...
# MIDI file 124 tokens: ['NOTE_ON_63_96', 'NOTE_ON_58_96', 'NOTE_ON_55_96', 'NOTE_ON_51_96', 'TIME_SHIFT_13', 'NOTE_OFF_63', 'NOTE_ON_67_96', 'NOTE_OFF_58', 'NOTE_ON_63_96', 'NOTE_OFF_55', 'NOTE_ON_58_96', 'TIME_SHIFT_13', 'NOTE_OFF_67', 'NOTE_ON_70_96', 'NOTE_OFF_63', 'NOTE_ON_67_96', 'NOTE_OFF_58', 'NOTE_ON_63_96', 'TIME_SHIFT_6', 'NOTE_OFF_51'] ...
# MIDI file 125 tokens: ['TIME_SHIFT_38', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_43_96', 'TIME_SHIFT_6', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'TIME_SHIFT_12'] ...
# MIDI file 126 tokens: ['TIME_SHIFT_38', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_47_96', 'TIME_SHIFT_12', 'NOTE_OFF_66', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'NOTE_OFF_47', 'NOTE_ON_54_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_57'] ...
# MIDI file 127 tokens: ['NOTE_ON_69_96', 'NOTE_ON_66_96', 'NOTE_ON_57_96', 'NOTE_ON_50_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_67_96', 'NOTE_OFF_66', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_57_96', 'NOTE_OFF_50', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_66_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'TIME_SHIFT_6', 'NOTE_OFF_66'] ...
# MIDI file 128 tokens: ['NOTE_ON_64_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'NOTE_OFF_52', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_59_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_54', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_64'] ...
# MIDI file 129 tokens: ['NOTE_ON_66_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_54', 'NOTE_ON_56_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_61', 'NOTE_ON_61_96', 'NOTE_OFF_59', 'NOTE_ON_61_96', 'NOTE_OFF_56', 'NOTE_ON_57_96', 'TIME_SHIFT_12', 'NOTE_OFF_66'] ...
# MIDI file 130 tokens: ['NOTE_ON_69_96', 'NOTE_ON_65_96', 'NOTE_ON_60_96', 'NOTE_ON_53_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_70_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_53', 'NOTE_ON_50_96', 'TIME_SHIFT_12', 'NOTE_OFF_70', 'NOTE_ON_72_96', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_60_96'] ...
# MIDI file 131 tokens: ['NOTE_ON_43_96', 'TIME_SHIFT_4', 'NOTE_ON_67_96', 'TIME_SHIFT_4', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'TIME_SHIFT_4', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'TIME_SHIFT_4', 'NOTE_OFF_71', 'NOTE_ON_74_96', 'TIME_SHIFT_4', 'NOTE_OFF_74', 'NOTE_ON_72_96', 'NOTE_OFF_67'] ...
# MIDI file 132 tokens: ['NOTE_ON_43_96', 'TIME_SHIFT_4', 'NOTE_ON_67_96', 'TIME_SHIFT_4', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'TIME_SHIFT_4', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'TIME_SHIFT_4', 'NOTE_OFF_71', 'NOTE_ON_74_96', 'TIME_SHIFT_4', 'NOTE_OFF_74', 'NOTE_ON_72_96', 'NOTE_OFF_67'] ...
# MIDI file 133 tokens: ['TIME_SHIFT_36', 'NOTE_ON_65_96', 'NOTE_ON_60_96', 'NOTE_ON_56_96', 'NOTE_ON_53_96', 'TIME_SHIFT_6', 'NOTE_OFF_56', 'NOTE_ON_58_96', 'NOTE_OFF_53', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_56_96', 'TIME_SHIFT_12'] ...
# MIDI file 134 tokens: ['TIME_SHIFT_38', 'NOTE_ON_66_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'NOTE_ON_54_96', 'TIME_SHIFT_6', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_54', 'NOTE_ON_56_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_61', 'NOTE_ON_61_96', 'NOTE_OFF_59', 'NOTE_ON_61_96', 'NOTE_OFF_56', 'NOTE_ON_57_96', 'TIME_SHIFT_12'] ...
# MIDI file 135 tokens: ['TIME_SHIFT_38', 'NOTE_ON_72_96', 'NOTE_ON_64_96', 'NOTE_ON_55_96', 'NOTE_ON_48_96', 'NOTE_ON_72_96', 'NOTE_ON_64_96', 'TIME_SHIFT_6', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_72', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_48', 'NOTE_ON_55_96', 'NOTE_OFF_72'] ...
# ...
# MIDI file 476 tokens: ['TIME_SHIFT_47', 'NOTE_ON_65_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_53_96', 'NOTE_ON_53_96', 'NOTE_ON_65_96', 'NOTE_ON_65_96', 'TIME_SHIFT_16', 'NOTE_OFF_65', 'NOTE_ON_72_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'NOTE_OFF_53', 'NOTE_ON_52_96', 'NOTE_OFF_53', 'NOTE_ON_52_96', 'NOTE_OFF_65'] ...
# MIDI file 477 tokens: ['NOTE_ON_41_96', 'TIME_SHIFT_14', 'NOTE_ON_65_96', 'TIME_SHIFT_7', 'NOTE_OFF_41', 'NOTE_ON_53_96', 'NOTE_OFF_65', 'NOTE_ON_72_96', 'TIME_SHIFT_14', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'TIME_SHIFT_7', 'NOTE_OFF_74', 'NOTE_ON_70_96', 'TIME_SHIFT_14', 'NOTE_OFF_70', 'NOTE_ON_69_96', 'TIME_SHIFT_7', 'NOTE_OFF_53', 'NOTE_ON_52_96'] ...
# MIDI file 478 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_50_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_70_96', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_50', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_70', 'NOTE_ON_69_96', 'NOTE_OFF_67', 'NOTE_ON_66_96', 'NOTE_OFF_62'] ...
# MIDI file 479 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_61', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_61_96', 'NOTE_OFF_57', 'NOTE_ON_45_96', 'TIME_SHIFT_6'] ...
# MIDI file 480 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_61', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_61_96', 'NOTE_OFF_57', 'NOTE_ON_45_96', 'TIME_SHIFT_6'] ...
# MIDI file 481 tokens: ['TIME_SHIFT_41', 'NOTE_ON_71_96', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_52_96', 'TIME_SHIFT_7', 'NOTE_OFF_64', 'NOTE_ON_62_96', 'TIME_SHIFT_7', 'NOTE_OFF_71', 'NOTE_ON_70_96', 'NOTE_OFF_67', 'NOTE_ON_66_96', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'NOTE_OFF_52', 'NOTE_ON_54_96', 'TIME_SHIFT_7', 'NOTE_OFF_54', 'NOTE_ON_52_96'] ...
# MIDI file 482 tokens: ['TIME_SHIFT_41', 'NOTE_ON_69_96', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_50_96', 'TIME_SHIFT_7', 'NOTE_OFF_62', 'NOTE_ON_60_96', 'TIME_SHIFT_7', 'NOTE_OFF_69', 'NOTE_ON_68_96', 'NOTE_OFF_65', 'NOTE_ON_64_96', 'NOTE_OFF_60', 'NOTE_ON_59_96', 'NOTE_OFF_50', 'NOTE_ON_52_96', 'TIME_SHIFT_7', 'NOTE_OFF_52', 'NOTE_ON_50_96'] ...
# MIDI file 483 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_63_96', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_60_96', 'TIME_SHIFT_6', 'NOTE_OFF_60', 'NOTE_ON_58_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96'] ...
# MIDI file 484 tokens: ['NOTE_ON_46_96', 'TIME_SHIFT_12', 'NOTE_ON_62_96', 'TIME_SHIFT_12', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_46', 'TIME_SHIFT_12', 'NOTE_OFF_62', 'NOTE_ON_65_96', 'NOTE_ON_58_96', 'TIME_SHIFT_3', 'NOTE_OFF_65', 'NOTE_ON_63_96', 'TIME_SHIFT_3', 'NOTE_OFF_63', 'NOTE_ON_62_96', 'TIME_SHIFT_3', 'NOTE_OFF_62', 'NOTE_ON_63_96'] ...
# MIDI file 485 tokens: ['TIME_SHIFT_39', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_43_96', 'TIME_SHIFT_7', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'TIME_SHIFT_7', 'NOTE_OFF_69', 'NOTE_ON_70_96', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'TIME_SHIFT_7'] ...
# MIDI file 486 tokens: ['TIME_SHIFT_38', 'NOTE_ON_64_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_40_96', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_66', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'NOTE_OFF_40', 'NOTE_OFF_52'] ...
# MIDI file 487 tokens: ['NOTE_ON_40_96', 'TIME_SHIFT_14', 'NOTE_ON_71_96', 'NOTE_OFF_40', 'TIME_SHIFT_7', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'TIME_SHIFT_7', 'NOTE_OFF_71', 'NOTE_ON_76_96', 'TIME_SHIFT_14', 'NOTE_OFF_76', 'NOTE_ON_71_96', 'NOTE_ON_68_96', 'NOTE_ON_64_96', 'NOTE_ON_52_96', 'NOTE_ON_52_96', 'NOTE_ON_52_96', 'NOTE_ON_52_96', 'TIME_SHIFT_7'] ...
# MIDI file 488 tokens: ['TIME_SHIFT_39', 'NOTE_ON_71_96', 'NOTE_ON_68_96', 'NOTE_ON_64_96', 'NOTE_ON_52_96', 'TIME_SHIFT_13', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_68', 'NOTE_ON_66_96', 'NOTE_OFF_64', 'NOTE_ON_59_96', 'NOTE_OFF_52', 'NOTE_ON_52_96', 'TIME_SHIFT_7', 'NOTE_OFF_66', 'NOTE_ON_68_96', 'TIME_SHIFT_7', 'NOTE_OFF_71', 'NOTE_ON_71_96'] ...
# MIDI file 489 tokens: ['NOTE_ON_74_96', 'NOTE_ON_67_96', 'NOTE_ON_58_96', 'NOTE_ON_55_96', 'TIME_SHIFT_26', 'NOTE_OFF_74', 'NOTE_ON_77_96', 'NOTE_OFF_67', 'NOTE_ON_65_96', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_57_96', 'TIME_SHIFT_26', 'NOTE_OFF_77', 'NOTE_ON_74_96', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_60', 'NOTE_ON_62_96'] ...
# MIDI file 490 tokens: ['NOTE_ON_62_96', 'NOTE_ON_57_96', 'NOTE_ON_54_96', 'NOTE_ON_50_96', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_50', 'NOTE_ON_49_96', 'NOTE_OFF_50', 'NOTE_ON_49_96', 'TIME_SHIFT_6', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_62_96', 'NOTE_OFF_54', 'NOTE_ON_54_96', 'NOTE_OFF_49', 'NOTE_ON_47_96', 'NOTE_OFF_49'] ...
# MIDI file 491 tokens: ['TIME_SHIFT_38', 'NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_46_96', 'NOTE_ON_82_96', 'TIME_SHIFT_12', 'NOTE_OFF_65', 'NOTE_ON_70_96', 'NOTE_OFF_62', 'NOTE_ON_65_96', 'NOTE_OFF_58', 'NOTE_ON_62_96', 'NOTE_OFF_46', 'NOTE_ON_58_96', 'NOTE_OFF_82', 'NOTE_ON_77_96', 'TIME_SHIFT_12', 'NOTE_OFF_70', 'NOTE_ON_72_96'] ...
# MIDI file 492 tokens: ['TIME_SHIFT_38', 'NOTE_ON_74_96', 'NOTE_ON_70_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_46_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_70_96', 'NOTE_OFF_70', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_63_96', 'NOTE_OFF_58', 'NOTE_ON_63_96', 'NOTE_OFF_46', 'NOTE_ON_51_96', 'TIME_SHIFT_6', 'NOTE_OFF_63', 'NOTE_ON_62_96'] ...
# MIDI file 493 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'NOTE_ON_43_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_70_96', 'NOTE_OFF_62', 'NOTE_ON_67_96', 'NOTE_OFF_60', 'NOTE_ON_62_96', 'NOTE_OFF_43', 'NOTE_ON_55_96', 'TIME_SHIFT_6'] ...
# MIDI file 494 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_65_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_55', 'NOTE_ON_53_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_71_96'] ...
# MIDI file 495 tokens: ['TIME_SHIFT_25', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_66_96', 'NOTE_OFF_61', 'NOTE_ON_61_96', 'NOTE_OFF_57', 'NOTE_ON_54_96', 'TIME_SHIFT_25', 'NOTE_OFF_69', 'NOTE_ON_68_96', 'NOTE_OFF_66', 'NOTE_ON_64_96', 'NOTE_OFF_61'] ...
# MIDI file 496 tokens: ['TIME_SHIFT_38', 'NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_55_96', 'NOTE_ON_47_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_62', 'NOTE_ON_63_96', 'NOTE_OFF_55', 'NOTE_ON_60_96', 'NOTE_OFF_47', 'NOTE_ON_48_96', 'TIME_SHIFT_6', 'NOTE_OFF_48', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_67', 'NOTE_ON_67_96'] ...
# MIDI file 497 tokens: ['TIME_SHIFT_38', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_57_96', 'NOTE_ON_49_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_65_96', 'NOTE_OFF_57', 'NOTE_ON_62_96', 'NOTE_OFF_49', 'NOTE_ON_50_96', 'TIME_SHIFT_6', 'NOTE_OFF_50', 'NOTE_ON_52_96', 'TIME_SHIFT_6', 'NOTE_OFF_69', 'NOTE_ON_69_96'] ...
# MIDI file 498 tokens: ['NOTE_ON_72_96', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_79_96', 'NOTE_ON_72_96', 'NOTE_ON_76_96', 'NOTE_ON_48_96', 'TIME_SHIFT_8', 'NOTE_OFF_72', 'NOTE_ON_67_96', 'NOTE_OFF_48', 'NOTE_ON_48_96', 'TIME_SHIFT_8', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_59_96'] ...
# MIDI file 499 tokens: ['NOTE_ON_72_96', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'TIME_SHIFT_15', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_59_96', 'NOTE_OFF_60', 'NOTE_ON_55_96', 'TIME_SHIFT_8', 'NOTE_OFF_74', 'NOTE_ON_76_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_60_96'] ...
# MIDI file 500 tokens: ['TIME_SHIFT_45', 'NOTE_ON_65_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_53_96', 'TIME_SHIFT_8', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'NOTE_OFF_57', 'NOTE_ON_58_96', 'TIME_SHIFT_8', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_60', 'NOTE_ON_65_96', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'NOTE_OFF_53', 'NOTE_ON_53_96', 'TIME_SHIFT_15'] ...
# MIDI file 501 tokens: ['TIME_SHIFT_45', 'NOTE_ON_65_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_53_96', 'TIME_SHIFT_8', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'NOTE_OFF_57', 'NOTE_ON_58_96', 'TIME_SHIFT_8', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_60', 'NOTE_ON_65_96', 'NOTE_OFF_58', 'NOTE_ON_60_96', 'NOTE_OFF_53', 'NOTE_ON_53_96', 'TIME_SHIFT_15'] ...
# MIDI file 502 tokens: ['TIME_SHIFT_45', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_61_96', 'NOTE_ON_45_96', 'NOTE_ON_45_96', 'NOTE_ON_69_96', 'TIME_SHIFT_8', 'NOTE_OFF_64', 'NOTE_ON_65_96', 'NOTE_OFF_45', 'NOTE_ON_45_96', 'TIME_SHIFT_4', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'TIME_SHIFT_4', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_67', 'NOTE_ON_65_96'] ...
# MIDI file 503 tokens: ['TIME_SHIFT_41', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_61_96', 'NOTE_ON_45_96', 'TIME_SHIFT_7', 'NOTE_OFF_64', 'NOTE_ON_65_96', 'TIME_SHIFT_3', 'NOTE_OFF_65', 'NOTE_ON_67_96', 'TIME_SHIFT_3', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_67', 'NOTE_ON_65_96', 'NOTE_OFF_61', 'NOTE_ON_62_96', 'NOTE_OFF_45', 'NOTE_ON_50_96'] ...
# MIDI file 504 tokens: ['NOTE_ON_72_96', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_59_96', 'NOTE_OFF_48', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_76_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_60_96'] ...
# MIDI file 505 tokens: ['NOTE_ON_72_96', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_59_96', 'NOTE_OFF_48', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_76_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_60_96'] ...
# MIDI file 506 tokens: ['NOTE_ON_72_96', 'NOTE_ON_67_96', 'NOTE_ON_64_96', 'NOTE_ON_48_96', 'TIME_SHIFT_12', 'NOTE_OFF_72', 'NOTE_ON_74_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_59_96', 'NOTE_OFF_48', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_74', 'NOTE_ON_76_96', 'NOTE_OFF_67', 'NOTE_ON_67_96', 'NOTE_OFF_59', 'NOTE_ON_60_96'] ...
# MIDI file 507 tokens: ['NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'TIME_SHIFT_14', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_60', 'NOTE_ON_59_96', 'NOTE_OFF_57', 'NOTE_ON_56_96', 'NOTE_OFF_57', 'NOTE_ON_56_96', 'TIME_SHIFT_14', 'NOTE_OFF_71', 'NOTE_ON_72_96', 'NOTE_OFF_64'] ...
# MIDI file 508 tokens: ['NOTE_ON_65_96', 'NOTE_ON_62_96', 'NOTE_ON_58_96', 'TIME_SHIFT_11', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_58', 'NOTE_ON_58_96', 'TIME_SHIFT_11', 'NOTE_OFF_65', 'NOTE_ON_65_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_58', 'NOTE_ON_58_96', 'TIME_SHIFT_11', 'NOTE_ON_74_96', 'NOTE_ON_70_96'] ...
# MIDI file 509 tokens: ['TIME_SHIFT_43', 'NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_60_96', 'NOTE_ON_45_96', 'TIME_SHIFT_14', 'NOTE_OFF_69', 'NOTE_ON_69_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_60', 'NOTE_ON_60_96', 'NOTE_OFF_45', 'NOTE_ON_57_96', 'TIME_SHIFT_14', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_60'] ...
# MIDI file 510 tokens: ['TIME_SHIFT_21', 'NOTE_ON_74_96', 'NOTE_ON_69_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_62_96', 'TIME_SHIFT_5', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'TIME_SHIFT_5', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_61', 'NOTE_ON_59_96'] ...
# MIDI file 511 tokens: ['TIME_SHIFT_21', 'NOTE_ON_74_96', 'NOTE_ON_69_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'TIME_SHIFT_5', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'TIME_SHIFT_5', 'NOTE_OFF_74', 'NOTE_ON_74_96', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_66', 'NOTE_ON_66_96', 'NOTE_OFF_61', 'NOTE_ON_59_96', 'TIME_SHIFT_10', 'NOTE_OFF_71', 'NOTE_ON_69_96'] ...
# MIDI file 512 tokens: ['NOTE_ON_69_96', 'NOTE_ON_64_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'NOTE_ON_45_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_61', 'NOTE_ON_64_96', 'NOTE_OFF_57', 'NOTE_ON_56_96', 'NOTE_OFF_45', 'NOTE_ON_44_96', 'TIME_SHIFT_12', 'NOTE_OFF_71', 'NOTE_ON_73_96', 'NOTE_OFF_64'] ...
# MIDI file 513 tokens: ['NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'NOTE_ON_43_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_59', 'NOTE_ON_62_96', 'NOTE_OFF_55', 'NOTE_ON_54_96', 'NOTE_OFF_43', 'NOTE_ON_42_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_62'] ...
# MIDI file 514 tokens: ['TIME_SHIFT_38', 'NOTE_ON_72_96', 'NOTE_ON_64_96', 'NOTE_ON_55_96', 'NOTE_ON_48_96', 'NOTE_ON_79_96', 'TIME_SHIFT_6', 'NOTE_OFF_79', 'NOTE_ON_77_96', 'TIME_SHIFT_6', 'NOTE_OFF_72', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_55', 'NOTE_ON_60_96', 'NOTE_OFF_48', 'NOTE_ON_60_96', 'NOTE_OFF_77', 'NOTE_ON_76_96'] ...
# MIDI file 515 tokens: ['NOTE_ON_67_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'NOTE_ON_55_96', 'TIME_SHIFT_12', 'NOTE_OFF_67', 'NOTE_ON_69_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'NOTE_OFF_55', 'NOTE_ON_54_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_71_96', 'NOTE_OFF_62', 'NOTE_ON_62_96', 'NOTE_OFF_57', 'NOTE_ON_55_96'] ...
# MIDI file 516 tokens: ['TIME_SHIFT_38', 'NOTE_ON_72_96', 'NOTE_ON_64_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'NOTE_ON_57_96', 'TIME_SHIFT_6', 'NOTE_OFF_57', 'NOTE_ON_59_96', 'TIME_SHIFT_6', 'NOTE_OFF_72', 'NOTE_ON_67_96', 'NOTE_OFF_64', 'NOTE_ON_64_96', 'NOTE_OFF_59', 'NOTE_ON_60_96', 'NOTE_OFF_57', 'NOTE_ON_52_96', 'NOTE_OFF_57', 'NOTE_ON_52_96'] ...
# MIDI file 517 tokens: ['TIME_SHIFT_38', 'NOTE_ON_62_96', 'NOTE_ON_57_96', 'NOTE_ON_54_96', 'NOTE_ON_50_96', 'TIME_SHIFT_12', 'NOTE_OFF_62', 'NOTE_ON_69_96', 'NOTE_OFF_57', 'NOTE_ON_57_96', 'NOTE_OFF_54', 'NOTE_ON_52_96', 'NOTE_OFF_50', 'NOTE_ON_49_96', 'TIME_SHIFT_12', 'NOTE_OFF_69', 'NOTE_ON_66_96', 'NOTE_OFF_57', 'NOTE_ON_57_96', 'NOTE_OFF_52'] ...
# MIDI file 518 tokens: ['NOTE_ON_71_96', 'NOTE_ON_66_96', 'NOTE_ON_62_96', 'NOTE_ON_59_96', 'TIME_SHIFT_7', 'NOTE_OFF_59', 'NOTE_ON_57_96', 'TIME_SHIFT_7', 'NOTE_OFF_71', 'NOTE_ON_71_96', 'NOTE_OFF_66', 'NOTE_ON_64_96', 'NOTE_OFF_62', 'NOTE_ON_61_96', 'NOTE_OFF_57', 'NOTE_ON_55_96', 'TIME_SHIFT_7', 'NOTE_OFF_61', 'NOTE_ON_59_96', 'TIME_SHIFT_7'] ...
# Number of sequences: 519
# Sample sequence length: 711
# Vocabulary size: 315
# Sample tokens: ['<PAD>', '<SOS>', '<EOS>', '<UNK>', 'TIME_SHIFT_39', 'NOTE_ON_69_96', 'NOTE_ON_61_96', 'NOTE_ON_57_96', 'NOTE_ON_54_96', 'TIME_SHIFT_7']
# Epoch 1/20, Loss: 5.1431
# Epoch 2/20, Loss: 4.1056
# Epoch 3/20, Loss: 3.7628
# Epoch 4/20, Loss: 3.3709
# Epoch 5/20, Loss: 3.0864
# Epoch 6/20, Loss: 2.8762
# Epoch 7/20, Loss: 2.6866
# Epoch 8/20, Loss: 2.5575
# Epoch 9/20, Loss: 2.4498
# Epoch 10/20, Loss: 2.3329
# Epoch 11/20, Loss: 2.2298
# Epoch 12/20, Loss: 2.1549
# Epoch 13/20, Loss: 2.0933
# Epoch 14/20, Loss: 2.0241
# Epoch 15/20, Loss: 1.9449
# Epoch 16/20, Loss: 1.8787
# Epoch 17/20, Loss: 1.8191
# Epoch 18/20, Loss: 1.7690
# Epoch 19/20, Loss: 1.7035
# Epoch 20/20, Loss: 1.6657
# Model saved as music_vae.pth

# %%
from midi2audio import FluidSynth
# sf2_path = 'path/to/sf2'  # path to sound font file
midi_file = "C:/Users/User/Document/Class/CS4990/GenAI/generated_output_with_temperature.mid" 
FluidSynth().play_midi("generated_output_with_temperature.mid")
# music = PrettyMIDI(midi_file=midi_file)
# waveform = music.fluidsynth()
# Audio(waveform, rate=44100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 4
#       2 # sf2_path = 'path/to/sf2'  # path to sound font file
#       3 midi_file = "C:/Users/User/Document/Class/CS4990/GenAI/generated_output_with_temperature.mid"
# ----> 4 FluidSynth().play_midi("generated_output_with_temperature")
#       5 # music = PrettyMIDI(midi_file=midi_file)
#       6 # waveform = music.fluidsynth()
#       7 # Audio(waveform, rate=44100)
#
# File c:\Users\User\Documents\Class\CS4990\GenAI\.venv\Lib\site-packages\midi2audio.py:49, in FluidSynth.play_midi(self, midi_file)
#      48 def play_midi(self, midi_file):
# ---> 49     subprocess.call(['fluidsynth', '-i', self.sound_font, midi_file, '-r', str(self.sample_rate)])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:389, in call(timeout, *popenargs, **kwargs)
#     381 def call(*popenargs, timeout=None, **kwargs):
#     382     """Run command with arguments.  Wait for command to complete or
#     383     timeout, then return the returncode attribute.
#     384
#    (...)    387     retcode = call(["ls", "-l"])
#     388     """
# --> 389     with Popen(*popenargs, **kwargs) as p:
#     390         try:
#     391             return p.wait(timeout=timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)   1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %%
# !fluidsynth
# Out:
# 'fluidsynth' is not recognized as an internal or external command,
# operable program or batch file.
